# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\ungdu\Downloads\PhamThuyDung_20521214_Lab_3\wine_data.csv')
print(df)
# Out:
#      Label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
df = df.drop('Label', axis=1)

# %%
import seaborn as sns

# %%
new_dataset = pd.read_csv(r'C:\Users\ungdu\Downloads\PhamThuyDung_20521214_Lab_3\wine_data.csv')
sns.set_theme(style="ticks")
sns.pairplot(new_dataset, hue='Proline')

# %%
dataplot=sns.heatmap(new_dataset.corr())
